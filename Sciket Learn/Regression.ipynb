# %%
import pandas as pd
import numpy as np
import matplotlib as mlp
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://gist.githubusercontent.com/nstokoe/7d4717e96c21b8ad04ec91f361b000cb/raw/bf95a2e30fceb9f2ae990eac8379fc7d844a0196/weight-height.csv')

# %%
data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
data.shape
# Out:
# (10000, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
data.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data.Height.values
# Out:
# array([73.84701702, 68.78190405, 74.11010539, ..., 63.86799221,
#        69.03424313, 61.94424588])

# %%
data.Weight.values
# Out:
# array([241.89356318, 162.31047252, 212.74085556, ..., 128.47531878,
#        163.85246135, 113.64910268])

# %% [markdown]
# ## train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.Height.values
y = data.Weight.values
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3)
display("X test : ",xtrain)
display("X train : ",xtest)
display("Y test : ",ytrain)
display("Y train : ",ytest)
# Out:
# 'X test : '
# array([65.18612139, 67.40540788, 65.27433111, ..., 64.44349555,
#        72.12375124, 70.97870259])
# 'X train : '
# array([68.00008113, 61.0782176 , 66.80247106, ..., 66.33428146,
#        64.49339476, 58.75125363])
# 'Y test : '
# array([165.02801264, 164.57439129, 136.50850617, ..., 151.52394728,
#        203.37296541, 206.52297405])
# 'Y train : '
# array([181.14604197, 116.43173231, 147.65498575, ..., 165.36827647,
#        159.45606578,  97.7224906 ])

# %%
display(len(x))
display(len(y))
# Out:
# 10000
# 10000

# %%
display(x[0])
display(y[0])
# Out:
# 73.847017017515
# 241.893563180437

# %%
fig, ax = plt.subplots(figsize= (7,4.6))
x = data.Height.values
y = data.Weight.values
ax.scatter(x,y)

# %% [markdown]
# ### Line function
# * y = wx + b

# %%
def equation(x , w, b = 0):
    return w*x + b

# %% [markdown]
# ### Loss Function

# %%
def mean_square_error(y_true, y_prediction):
    s = (y_true - y_prediction) ** 2
    return np.sqrt(s.mean())

# %%
fig, ax = plt.subplots(1,2,figsize = (10,5))
data.plot.scatter(x = 'Height',y = 'Weight',ax=ax[0])
bs = [-100, -50, 0 , 50 , 100 , 150]
mses = []
for b in bs:
    y_pred = equation(x,2,b)
    mse = mean_square_error(y,y_pred)
    mses.append(mse)
    ax[0].plot(x, y_pred)
    
    
ax[1].plot(bs, mses,'o-')

# %%
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(x = data.Height.values, y = data.Weight.values)
bs = [50]
mses = []
for b in bs:
    y_pred = equation(x,2,b)
    mse = mean_square_error(y,y_pred)
    mses.append(mse)
    ax.plot(x, y_pred,'red')

# %%
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(x = data.Height.values, y = data.Weight.values)
y_pred = equation(x,7.6609,-348.16) 
ax.plot(x,y_pred,'orange')
